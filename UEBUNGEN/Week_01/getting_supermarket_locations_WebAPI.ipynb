# %% [markdown]
# # Getting all available Swiss supermarkets using the overpass Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import folium
from pandas import json_normalize

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# /workspaces/DA_Project/UEBUNGEN/Week_01

# %% [markdown]
# ## Overpass turbo query to get all available supermarkets in Switzerland

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["shop"="supermarket"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('supermarkets.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = json_normalize(data)

# Number of rows and columns
print(df.shape)

# First rows
df.head()
# Out:
# (3407, 248)
#    type        id        lat       lon tags.brand tags.brand:wikidata  \
# 0  node  33126515  47.155616  9.037915       Spar             Q610492
# 1  node  36726161  47.226191  8.980329     Migros             Q680727
# 2  node  39768209  47.225069  8.969981       Coop             Q432564
# 3  node  39947904  47.376732  8.542161       Coop             Q432564
# 4  node  48932835  47.375020  8.522895     Migros             Q680727
#
#   tags.brand:wikipedia tags.name  \
# 0   en:SPAR (retailer)      Spar
# 1            de:Migros    Migros
# 2                  NaN      Coop
# 3    de:Coop (Schweiz)      Coop
# 4                  NaN    Migros
#
#                                   tags.opening_hours    tags.shop  ...  \
# 0  Mo-Th 08:00-19:00; Fr 08:00-20:00; Sa 08:00-17:00  supermarket  ...
# 1  Mo-Th 08:00-19:00, Fr 08:00-20:00, Sa 07:30-17...  supermarket  ...
# 2                                                NaN  supermarket  ...
# 3                                  Mo-Sa 06:00-22:00  supermarket  ...
# 4                          Mo-Sa 08:00-21:00; PH off  supermarket  ...
#
#   tags.source:addr tags.opening_date tags.postid tags.diet:local  \
# 0              NaN               NaN         NaN             NaN
# 1              NaN               NaN         NaN             NaN
# 2              NaN               NaN         NaN             NaN
# 3              NaN               NaN         NaN             NaN
# 4              NaN               NaN         NaN             NaN
#
#   tags.payment:account_cards tags.diet:fish tags.diet:mediterranean  \
# 0                        NaN            NaN                     NaN
# 1                        NaN            NaN                     NaN
# 2                        NaN            NaN                     NaN
# 3                        NaN            NaN                     NaN
# 4                        NaN            NaN                     NaN
#
#   tags.diet:organic tags.diet:seafood tags.recycling:low_energy_bulbs
# 0               NaN               NaN                             NaN
# 1               NaN               NaN                             NaN
# 2               NaN               NaN                             NaN
# 3               NaN               NaN                             NaN
# 4               NaN               NaN                             NaN
#
# [5 rows x 248 columns]

# %% [markdown]
# ## Plot supermarkets on map

# %%
# Subset of supermarkets by brand
locations = df[["lat", "lon", "tags.brand", "tags.shop"]].loc[df["tags.brand"].isin(['Migros', 'Coop'])]
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                  popup=location_info["tags.brand"]).add_to(map)

# Plot map
map
# Out:
#          lat       lon tags.brand    tags.shop
# 1  47.226191  8.980329     Migros  supermarket
# 2  47.225069  8.969981       Coop  supermarket
# 3  47.376732  8.542161       Coop  supermarket
# 4  47.375020  8.522895     Migros  supermarket
# 7  47.491874  8.706448     Migros  supermarket
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_358e328a457187c2b2beaa8d181c9d35 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_358e328a457187c2b2beaa8d181c9d35&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_358e328a457187c2b2beaa8d181c9d35 = L.map(
#                 &quot;map_358e328a457187c2b2beaa8d181c9d35&quot;,
#                 {
#                     center: [47.00897594543035, 7.995502869032831],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_358e328a457187c2b2beaa8d181c9d35);
#
#
#
#
#
#             var tile_layer_3a0afc93181fe1750f99193562a974b8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_358e328a457187c2b2beaa8d181c9d35);
#
#
#             var marker_f58ef28c271a17531f26e806a8e72c85 = L.marker(
#                 [47.2261912, 8.9803292],
#                 {}
#             ).addTo(map_358e328a457187c2b2beaa8d181c9d35);
#
#
#         var popup_8544da8fc6579500056d73f30919aa33 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_84b8285551d4d4e468dd33c4c907d2da = $(`&lt;div id=&quot;html_84b8285551d4d4e468dd33c4c907d2da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_8544da8fc6579500056d73f30919aa33.setContent(html_84b8285551d4d4e468dd33c4c907d2da);
#
#
#
#         marker_f58ef28c271a17531f26e806a8e72c85.bindPopup(popup_8544da8fc6579500056d73f30919aa33)
#         ;
#
#
#
#
#             var marker_20c81bfedbd131aed05fa412eb7eff2d = L.marker(
#                 [47.2250689, 8.9699805],
#                 {}
#             ).addTo(map_358e328a457187c2b2beaa8d181c9d35);
#
#
#         var popup_34bd69481d675c6f69bb29b6f27929ec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_06d36c7210f687207a0ec88413e67cdc = $(`&lt;div id=&quot;html_06d36c7210f687207a0ec88413e67cdc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_34bd69481d675c6f69bb29b6f27929ec.setContent(html_06d36c7210f687207a0ec88413e67cdc);
#
#
#
#         marker_20c81bfedbd131aed05fa412eb7eff2d.bindPopup(popup_34bd69481d675c6f69bb29b6f27929ec)
#         ;
#
#
#
#
#             var marker_7e71be9f78660476580af8cf04adc29f = L.marker(
#                 [47.3767316, 8.5421608],
#                 {}
#             ).addTo(map_358e328a457187c2b2beaa8d181c9d35);
#
#
#         var popup_a2b5c5bab4decd7981b3eb2c5d4d36d2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2636e9248371e9ee85b337d46176fa0d = $(`&lt;div id=&quot;html_2636e9248371e9ee85b337d46176fa0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_a2b5c5bab4decd7981b3eb2c5d4d36d2.setContent(html_2636e9248371e9ee85b337d46176fa0d);
#
#
#
#         marker_7e71be9f78660476580af8cf04adc29f.bindPopup(popup_a2b5c5bab4decd7981b3eb2c5d4d36d2)
#         ;
#
#
#
#
#             var marker_9d11530b79c41461d3b27777e239dae1 = L.marker(
#                 [47.37502, 8.522895],
#                 {}
#             ).addTo(map_358e328a457187c2b2beaa8d181c9d35);
#
#
#         var popup_9bbceef63d40a0060d111d576c586f24 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_abcc9d801b21cfd4e5938835d38b2c2f = $(`&lt;div id=&quot;html_abcc9d801b21cfd4e5938835d38b2c2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_9bbceef63d40a0060d111d576c586f24.setContent(html_abcc9d801b21cfd4e5938835d38b2c2f);
#
#
#
#         marker_9d11530b79c41461d3b27777e239dae1.bindPopup(popup_9bbceef63d40a0060d111d576c586f24)
#         ;
#
#
#
#
#             var marker_884dacde70e2bf8a94324f269687307f = L.marker(
#                 [47.4918744, 8.7064484],
#                 {}
#             ).addTo(map_358e328a457187c2b2beaa8d181c9d35);
#
#
#         var popup_60e619e2b6dd82e4bd3e6b2bc1796075 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1e9885021de1eeccd129d23833cb4c4e = $(`&lt;div id=&quot;html_1e9885021de1eeccd129d23833cb4c4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_60e619e2b6dd82e4bd3e6b2bc1796075.setContent(html_1e9885021de1eeccd129d23833cb4c4e);
#
#
#
#         marker_884dacde70e2bf8a94324f269687307f.bindPopup(popup_60e619e2b6dd82e4bd3e6b2bc1796075)
#         ;
#
#
#
#
#             var marker_53da19a88134ea83600f3ae69b2a25f6 = L.marker(

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.2.0-1018-azure
# Datetime: 2024-01-04 21:44:42
# Python Version: 3.10.13
# -----------------------------------
