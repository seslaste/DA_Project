# %% [markdown]
# # Geocoding apartment addresses using the geoadmin API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import urllib
import fnmatch
import folium
import pandas as pd
from IPython.display import clear_output

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Get current working directory
print(os.getcwd())
# Out:
# /workspaces/DA_Project/Project/Additional/3

# %% [markdown]
# ## Geocoding a single address

# %% [markdown]
# ### Define base url for address search

# %%
# Define base url for address search
base_url= "https://api3.geo.admin.ch/rest/services/api/SearchServer?"

# Set up search parameters: address, origins and type
parameters = {"searchText": "8400",
              "origins": "address",
              "type": "locations",
             }

# Urllib.parse.urlencode turns parameters into url
print(f"{base_url}{urllib.parse.urlencode(parameters)}")
# Out:
# https://api3.geo.admin.ch/rest/services/api/SearchServer?searchText=8400&origins=address&type=locations

# %% [markdown]
# ### Server request & response

# %%
# Server request
r = requests.get(f"{base_url}{urllib.parse.urlencode(parameters)}")

# Get data in json-format
data = json.loads(r.content)
data

# Take only the first server response, convert to data frame with relevant infos
df = pd.DataFrame.from_dict(list(data.values())[0][0], orient='columns')
df.iloc[[1,4,5,6,11,12],:1]
# Out:
#                                            attrs
# featureId                              1150440_0
# label      Kreuzstrasse 1 <b>8400 Winterthur</b>
# lat                                    47.503555
# lon                                      8.72975
# x                                     262222.875
# y                                       697271.5

# %% [markdown]
# ## Geocoding multiple addresses

# %% [markdown]
# ### Importing apartment data

# %%
# Get current working directory
print(os.getcwd())

# Show all files in the directory
flist = fnmatch.filter(os.listdir('.'), '*.csv')
for i in flist:
    print(i)

# Read the data to a pandas data frame
df = pd.read_csv('bmw_data_prepared.csv', 
                 sep=',', 
                 encoding='utf-8')[ ['web-scraper-order', 
                'model_raw',
                'Location',
                'PLZ',
                'Year',
                'price',
                'km',
                'luxury',
                'competition',
                'xDrive',
                'automat',
                'km_cat',
                'km_per_year']][:1000] # first 1000 BMW adresses

# Get number of rows and columns
print(df.shape)

# Show first records
df.head(10)
# Out:
# /workspaces/DA_Project/Project/Additional/3
# bmw_data_geocoded.csv
# bmw_data_prepared.csv
# (990, 13)
#   web-scraper-order                                          model_raw  \
# 0      1705078003-1                     X3 xDrive 20d xLine Steptronic
# 1      1705078003-2                                               540i
# 2      1705078003-3  225xe iPerformance Active Tourer Steptronic M ...
# 3      1705078003-4                                       316i Compact
# 4      1705078003-5                                   530xi Steptronic
# 5      1705078003-6                           X5 xDrive 40d Steptronic
# 6      1705078003-7                                       525d Touring
# 7      1705078003-8               225i xDrive Active Tourer Steptronic
# 8      1705078003-9            435i Coupé xDrive Sport Line Steptronic
# 9     1705078003-10           X5 xDrive 48V 40d M Sport Pro Steptronic
#
#   Location   PLZ  Year   price        km  luxury  competition  xDrive  \
# 0       GE  1227  2016   22900  119500.0       0            0       1
# 1       BL  4461  2006   13750  124900.0       0            0       0
# 2       BL  4460  2019   28800   28950.0       0            0       0
# 3       ZG  6300  2000    1100  248013.0       0            0       0
# 4       LU  6010  2008   10900  160000.0       0            0       0
# 5       TI  6964  2015   33900  125900.0       0            0       1
# 6       FR  1700  2004    3300  336000.0       0            0       0
# 7       BE  3400  2017   13500   97000.0       0            0       1
# 8       ZH  8157  2014   22950  112500.0       0            0       1
# 9       VD  1530  2024  112300       NaN       0            0       1
#
#    automat   km_cat  km_per_year
# 0        1  50-120k     14937.50
# 1        1    120k+      6938.89
# 2        1    0-50k      5790.00
# 3        1    120k+     10333.88
# 4        1    120k+     10000.00
# 5        1    120k+     13988.89
# 6        1    120k+     16800.00
# 7        1  50-120k     13857.14
# 8        1  50-120k     11250.00
# 9        1      NaN          NaN

# %% [markdown]
# ### Geocoding multiple apartment addresses using the geoadmin API

# %%
# Define base url
base_url= "https://api3.geo.admin.ch/rest/services/api/SearchServer?"

# Geocode list of adresses
geolocation = []
n = 1
for i in df['PLZ'].astype(str):
    
    print('Geocoding address', 
          n, 
          'out of', 
          len(df['PLZ']), 
          ':', 
          i)
    n=n+1
    clear_output(wait=True)
    
    try:
        # Set up search parameters - address, origins and type
        parameters = {"searchText": i,
                      "origins": "address",
                      "type": "locations",
                     }

        # Server request
        r = requests.get(f"{base_url}{urllib.parse.urlencode(parameters)}")

        # Get data
        data = json.loads(r.content)

        # Take first server response, convert to df with relevant infos
        df_loc = pd.DataFrame.from_dict(list(data.values())[0][0], 
                                        orient='columns')
        geolocation.append(df_loc.iloc[[5,6],0].astype(float))
    
    except:
        geolocation.append(pd.Series(data={'lat': None, 'lon': None}))
        

# Write lat and lon to df
df_loc = pd.DataFrame(geolocation, 
                      columns=("lat", "lon"), 
                      index=range(len(df['PLZ'])))
df['lat'] = df_loc['lat']
df['lon'] = df_loc['lon']
df.head(5)
# Out:
#   web-scraper-order                                          model_raw  \
# 0      1705078003-1                     X3 xDrive 20d xLine Steptronic
# 1      1705078003-2                                               540i
# 2      1705078003-3  225xe iPerformance Active Tourer Steptronic M ...
# 3      1705078003-4                                       316i Compact
# 4      1705078003-5                                   530xi Steptronic
#
#   Location   PLZ  Year  price        km  luxury  competition  xDrive  automat  \
# 0       GE  1227  2016  22900  119500.0       0            0       1        1
# 1       BL  4461  2006  13750  124900.0       0            0       0        1
# 2       BL  4460  2019  28800   28950.0       0            0       0        1
# 3       ZG  6300  2000   1100  248013.0       0            0       0        1
# 4       LU  6010  2008  10900  160000.0       0            0       0        1
#
#     km_cat  km_per_year        lat       lon
# 0  50-120k     14937.50  46.183849  6.138751
# 1    120k+      6938.89  47.462429  7.835723
# 2    0-50k      5790.00  47.467308  7.848388
# 3    120k+     10333.88  47.186596  8.499633
# 4    120k+     10000.00  47.044533  8.272661

# %% [markdown]
# ### Plot addresses on map

# %%
# Initialisierung der Map
m = folium.Map(location=[47.44, 8.65], zoom_start=10)

# Add lat/lon of addresses
df_sub = df.dropna()
for i in range(0, len(df_sub)):
    folium.Marker(location=(df_sub.iloc[i]['lat'], 
                            df_sub.iloc[i]['lon']), 
                  popup=df_sub.iloc[i]['PLZ']).add_to(m)

# Layer control
folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a1be757905782c7d9070fd9801395c9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a1be757905782c7d9070fd9801395c9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a1be757905782c7d9070fd9801395c9 = L.map(
#                 &quot;map_0a1be757905782c7d9070fd9801395c9&quot;,
#                 {
#                     center: [47.44, 8.65],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a4e215a888f0e74f5615fca04926ff10 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0a1be757905782c7d9070fd9801395c9);
#
#
#             var marker_0ba229458d5b74fd7b6028046f02bbc0 = L.marker(
#                 [46.1838493347168, 6.138751029968262],
#                 {}
#             ).addTo(map_0a1be757905782c7d9070fd9801395c9);
#
#
#         var popup_ed45a35721bb8d2f82fa4786422a2a9d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ec514b1d879cd7d6932a081739e12f7a = $(`&lt;div id=&quot;html_ec514b1d879cd7d6932a081739e12f7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1227&lt;/div&gt;`)[0];
#                 popup_ed45a35721bb8d2f82fa4786422a2a9d.setContent(html_ec514b1d879cd7d6932a081739e12f7a);
#
#
#
#         marker_0ba229458d5b74fd7b6028046f02bbc0.bindPopup(popup_ed45a35721bb8d2f82fa4786422a2a9d)
#         ;
#
#
#
#
#             var marker_be10203939e1e936fd91b23e21f2af3d = L.marker(
#                 [47.46242904663086, 7.835723400115967],
#                 {}
#             ).addTo(map_0a1be757905782c7d9070fd9801395c9);
#
#
#         var popup_c9a8b48bf1cca29ad67773d5aaa52a6f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7529c42a31079c8cb5f840379a2a9181 = $(`&lt;div id=&quot;html_7529c42a31079c8cb5f840379a2a9181&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4461&lt;/div&gt;`)[0];
#                 popup_c9a8b48bf1cca29ad67773d5aaa52a6f.setContent(html_7529c42a31079c8cb5f840379a2a9181);
#
#
#
#         marker_be10203939e1e936fd91b23e21f2af3d.bindPopup(popup_c9a8b48bf1cca29ad67773d5aaa52a6f)
#         ;
#
#
#
#
#             var marker_7c9fcb110b9392d00da85a0c0bce038f = L.marker(
#                 [47.467308044433594, 7.848388195037842],
#                 {}
#             ).addTo(map_0a1be757905782c7d9070fd9801395c9);
#
#
#         var popup_4633226c9dbf24339b60e0e611494dbd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4cc783fccc122d39bf344b94342dcf60 = $(`&lt;div id=&quot;html_4cc783fccc122d39bf344b94342dcf60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4460&lt;/div&gt;`)[0];
#                 popup_4633226c9dbf24339b60e0e611494dbd.setContent(html_4cc783fccc122d39bf344b94342dcf60);
#
#
#
#         marker_7c9fcb110b9392d00da85a0c0bce038f.bindPopup(popup_4633226c9dbf24339b60e0e611494dbd)
#         ;
#
#
#
#
#             var marker_a484a5420e4c33b42d42443f57904685 = L.marker(
#                 [47.18659591674805, 8.499632835388184],
#                 {}
#             ).addTo(map_0a1be757905782c7d9070fd9801395c9);
#
#
#         var popup_163983559bb6300d4e1a4e5236bb8f2f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53a2e8a2a7c2aad5ec15d6c92f572472 = $(`&lt;div id=&quot;html_53a2e8a2a7c2aad5ec15d6c92f572472&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;6300&lt;/div&gt;`)[0];
#                 popup_163983559bb6300d4e1a4e5236bb8f2f.setContent(html_53a2e8a2a7c2aad5ec15d6c92f572472);
#
#
#
#         marker_a484a5420e4c33b42d42443f57904685.bindPopup(popup_163983559bb6300d4e1a4e5236bb8f2f)
#         ;
#
#
#
#
#             var marker_35bc0cde26b2a37675b5883782bcecf9 = L.marker(
#                 [47.044532775878906, 8.272661209106445],
#                 {}
#             ).addTo(map_0a1be757905782c7d9070fd9801395c9);
#
#
#         var popup_e6ea4d87bf9eb8954036e1b1b60ea9da = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_615338ff9317f68ff5a588d80ad33c0e = $(`&lt;div id=&quot;html_615338ff9317f68ff5a588d80ad33c0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;6010&lt;/div&gt;`)[0];
#                 popup_e6ea4d87bf9eb8954036e1b1b60ea9da.setContent(html_615338ff9317f68ff5a588d80ad33c0e);
#
#
#
#         marker_35bc0cde26b2a37675b5883782bcecf9.bindPopup(popup_e6ea4d87bf9eb8954036e1b1b60ea9da)
#         ;
#
#
#
#
#             var marker_e79268c5d3bb476e27349ba3019de2ea = L.marker(
#                 [46.029708862

# %% [markdown]
# ### Save data to file

# %%
df.to_csv('bmw_data_geocoded.csv', 
           sep=",", 
           encoding='utf-8',
           index=False)

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.2.0-1018-azure
# Datetime: 2024-01-13 12:26:59
# Python Version: 3.10.13
# -----------------------------------
