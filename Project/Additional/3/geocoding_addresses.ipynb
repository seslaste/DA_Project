# %% [markdown]
# # Geocoding apartment addresses using the geoadmin API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import urllib
import fnmatch
import folium
import pandas as pd
from IPython.display import clear_output

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Get current working directory
print(os.getcwd())
# Out:
# /workspaces/DA_Project/Project/Additional/3

# %% [markdown]
# ## Geocoding a single address

# %% [markdown]
# ### Define base url for address search

# %%
# Define base url for address search
base_url= "https://api3.geo.admin.ch/rest/services/api/SearchServer?"

# Set up search parameters: address, origins and type
parameters = {"searchText": "8400",
              "origins": "address",
              "type": "locations",
             }

# Urllib.parse.urlencode turns parameters into url
print(f"{base_url}{urllib.parse.urlencode(parameters)}")
# Out:
# https://api3.geo.admin.ch/rest/services/api/SearchServer?searchText=8400&origins=address&type=locations

# %% [markdown]
# ### Server request & response

# %%
# Server request
r = requests.get(f"{base_url}{urllib.parse.urlencode(parameters)}")

# Get data in json-format
data = json.loads(r.content)
data

# Take only the first server response, convert to data frame with relevant infos
df = pd.DataFrame.from_dict(list(data.values())[0][0], orient='columns')
df.iloc[[1,4,5,6,11,12],:1]
# Out:
#                                            attrs
# featureId                              1150440_0
# label      Kreuzstrasse 1 <b>8400 Winterthur</b>
# lat                                    47.503555
# lon                                      8.72975
# x                                     262222.875
# y                                       697271.5

# %% [markdown]
# ## Geocoding multiple addresses

# %% [markdown]
# ### Importing apartment data

# %%
# Get current working directory
print(os.getcwd())

# Show all files in the directory
flist = fnmatch.filter(os.listdir('.'), '*.csv')
for i in flist:
    print(i)

# Read the data to a pandas data frame
df = pd.read_csv('bmw_data_prepared.csv', 
                 sep=',', 
                 encoding='utf-8')[ ['web-scraper-order', 
                'model_raw',
                'Location',
                'PLZ',
                'Year',
                'price',
                'km',
                'luxury',
                'competition',
                'xDrive',
                'automat',
                'km_cat',
                'km_per_year']][:1000] # first 100 apartment adresses

# Get number of rows and columns
print(df.shape)

# Show first records
df.head(10)
# Out:
# /workspaces/DA_Project/Project/Additional/3
# bmw_data_prepared.csv
# (990, 13)
#   web-scraper-order                                          model_raw  \
# 0      1705078003-1                     X3 xDrive 20d xLine Steptronic
# 1      1705078003-2                                               540i
# 2      1705078003-3  225xe iPerformance Active Tourer Steptronic M ...
# 3      1705078003-4                                       316i Compact
# 4      1705078003-5                                   530xi Steptronic
# 5      1705078003-6                           X5 xDrive 40d Steptronic
# 6      1705078003-7                                       525d Touring
# 7      1705078003-8               225i xDrive Active Tourer Steptronic
# 8      1705078003-9            435i Coupé xDrive Sport Line Steptronic
# 9     1705078003-10           X5 xDrive 48V 40d M Sport Pro Steptronic
#
#   Location   PLZ  Year   price        km  luxury  competition  xDrive  \
# 0       GE  1227  2016   22900  119500.0       0            0       1
# 1       BL  4461  2006   13750  124900.0       0            0       0
# 2       BL  4460  2019   28800   28950.0       0            0       0
# 3       ZG  6300  2000    1100  248013.0       0            0       0
# 4       LU  6010  2008   10900  160000.0       0            0       0
# 5       TI  6964  2015   33900  125900.0       0            0       1
# 6       FR  1700  2004    3300  336000.0       0            0       0
# 7       BE  3400  2017   13500   97000.0       0            0       1
# 8       ZH  8157  2014   22950  112500.0       0            0       1
# 9       VD  1530  2024  112300       NaN       0            0       1
#
#    automat   km_cat  km_per_year
# 0        1  50-120k     14937.50
# 1        1    120k+      6938.89
# 2        1    0-50k      5790.00
# 3        1    120k+     10333.88
# 4        1    120k+     10000.00
# 5        1    120k+     13988.89
# 6        1    120k+     16800.00
# 7        1  50-120k     13857.14
# 8        1  50-120k     11250.00
# 9        1      NaN          NaN

# %% [markdown]
# ### Geocoding multiple apartment addresses using the geoadmin API

# %%
# Define base url
base_url= "https://api3.geo.admin.ch/rest/services/api/SearchServer?"

# Geocode list of adresses
geolocation = []
n = 1
for i in df['PLZ'].astype(str):
    
    print('Geocoding address', 
          n, 
          'out of', 
          len(df['PLZ']), 
          ':', 
          i)
    n=n+1
    clear_output(wait=True)
    
    try:
        # Set up search parameters - address, origins and type
        parameters = {"searchText": i,
                      "origins": "address",
                      "type": "locations",
                     }

        # Server request
        r = requests.get(f"{base_url}{urllib.parse.urlencode(parameters)}")

        # Get data
        data = json.loads(r.content)

        # Take first server response, convert to df with relevant infos
        df_loc = pd.DataFrame.from_dict(list(data.values())[0][0], 
                                        orient='columns')
        geolocation.append(df_loc.iloc[[5,6],0].astype(float))
    
    except:
        geolocation.append(pd.Series(data={'lat': None, 'lon': None}))
        

# Write lat and lon to df
df_loc = pd.DataFrame(geolocation, 
                      columns=("lat", "lon"), 
                      index=range(len(df['PLZ'])))
df['lat'] = df_loc['lat']
df['lon'] = df_loc['lon']
df.head(5)
# Out:
#   web-scraper-order                                          model_raw  \
# 0      1705078003-1                     X3 xDrive 20d xLine Steptronic
# 1      1705078003-2                                               540i
# 2      1705078003-3  225xe iPerformance Active Tourer Steptronic M ...
# 3      1705078003-4                                       316i Compact
# 4      1705078003-5                                   530xi Steptronic
#
#   Location   PLZ  Year  price        km  luxury  competition  xDrive  automat  \
# 0       GE  1227  2016  22900  119500.0       0            0       1        1
# 1       BL  4461  2006  13750  124900.0       0            0       0        1
# 2       BL  4460  2019  28800   28950.0       0            0       0        1
# 3       ZG  6300  2000   1100  248013.0       0            0       0        1
# 4       LU  6010  2008  10900  160000.0       0            0       0        1
#
#     km_cat  km_per_year        lat       lon
# 0  50-120k     14937.50  46.183849  6.138751
# 1    120k+      6938.89  47.462429  7.835723
# 2    0-50k      5790.00  47.467308  7.848388
# 3    120k+     10333.88  47.186596  8.499633
# 4    120k+     10000.00  47.044533  8.272661

# %% [markdown]
# ### Plot addresses on map

# %%
# Initialisierung der Map
m = folium.Map(location=[47.44, 8.65], zoom_start=10)

# Add lat/lon of addresses
df_sub = df.dropna()
for i in range(0, len(df_sub)):
    folium.Marker(location=(df_sub.iloc[i]['lat'], 
                            df_sub.iloc[i]['lon']), 
                  popup=df_sub.iloc[i]['PLZ']).add_to(m)

# Layer control
folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac1788f4e8c56f04bc8ae113e52c865d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac1788f4e8c56f04bc8ae113e52c865d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ac1788f4e8c56f04bc8ae113e52c865d = L.map(
#                 &quot;map_ac1788f4e8c56f04bc8ae113e52c865d&quot;,
#                 {
#                     center: [47.44, 8.65],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f4fd3c023a334251e7992c6aece7e6ed = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ac1788f4e8c56f04bc8ae113e52c865d);
#
#
#             var marker_7708c8c7db693b9dda6f6c51d85beb00 = L.marker(
#                 [46.1838493347168, 6.138751029968262],
#                 {}
#             ).addTo(map_ac1788f4e8c56f04bc8ae113e52c865d);
#
#
#         var popup_25a86b288b9953340992ac12852b16fb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_91a5b5873b4f4ea64d93c559de3f5729 = $(`&lt;div id=&quot;html_91a5b5873b4f4ea64d93c559de3f5729&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1227&lt;/div&gt;`)[0];
#                 popup_25a86b288b9953340992ac12852b16fb.setContent(html_91a5b5873b4f4ea64d93c559de3f5729);
#
#
#
#         marker_7708c8c7db693b9dda6f6c51d85beb00.bindPopup(popup_25a86b288b9953340992ac12852b16fb)
#         ;
#
#
#
#
#             var marker_0aa7298a7f3a9a309e0dd13d2f3e653c = L.marker(
#                 [47.46242904663086, 7.835723400115967],
#                 {}
#             ).addTo(map_ac1788f4e8c56f04bc8ae113e52c865d);
#
#
#         var popup_dfa33d33faeb0f706146fe296d3d13f6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b74ba6b181a0e5771a621ea59c8e4637 = $(`&lt;div id=&quot;html_b74ba6b181a0e5771a621ea59c8e4637&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4461&lt;/div&gt;`)[0];
#                 popup_dfa33d33faeb0f706146fe296d3d13f6.setContent(html_b74ba6b181a0e5771a621ea59c8e4637);
#
#
#
#         marker_0aa7298a7f3a9a309e0dd13d2f3e653c.bindPopup(popup_dfa33d33faeb0f706146fe296d3d13f6)
#         ;
#
#
#
#
#             var marker_c98193e517017d22aa4796466467dfef = L.marker(
#                 [47.467308044433594, 7.848388195037842],
#                 {}
#             ).addTo(map_ac1788f4e8c56f04bc8ae113e52c865d);
#
#
#         var popup_d5774de25f36cc71fd138d1ddc6bb833 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b3a47659f4d1e537d532f1eeeb8ef3f3 = $(`&lt;div id=&quot;html_b3a47659f4d1e537d532f1eeeb8ef3f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4460&lt;/div&gt;`)[0];
#                 popup_d5774de25f36cc71fd138d1ddc6bb833.setContent(html_b3a47659f4d1e537d532f1eeeb8ef3f3);
#
#
#
#         marker_c98193e517017d22aa4796466467dfef.bindPopup(popup_d5774de25f36cc71fd138d1ddc6bb833)
#         ;
#
#
#
#
#             var marker_c2dc1112a6c351293ff939a496094311 = L.marker(
#                 [47.18659591674805, 8.499632835388184],
#                 {}
#             ).addTo(map_ac1788f4e8c56f04bc8ae113e52c865d);
#
#
#         var popup_bfdca18edf5ab62edf87830d4026eee5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0859513e7dccd75e0ea6aefbd114ea0a = $(`&lt;div id=&quot;html_0859513e7dccd75e0ea6aefbd114ea0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;6300&lt;/div&gt;`)[0];
#                 popup_bfdca18edf5ab62edf87830d4026eee5.setContent(html_0859513e7dccd75e0ea6aefbd114ea0a);
#
#
#
#         marker_c2dc1112a6c351293ff939a496094311.bindPopup(popup_bfdca18edf5ab62edf87830d4026eee5)
#         ;
#
#
#
#
#             var marker_084243cfd06f3e56feb21d551eefcd1d = L.marker(
#                 [47.044532775878906, 8.272661209106445],
#                 {}
#             ).addTo(map_ac1788f4e8c56f04bc8ae113e52c865d);
#
#
#         var popup_fb8c145c634f0ba241ed9c8067af0dc8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8071b3bfc80376c7dbac1807b2761959 = $(`&lt;div id=&quot;html_8071b3bfc80376c7dbac1807b2761959&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;6010&lt;/div&gt;`)[0];
#                 popup_fb8c145c634f0ba241ed9c8067af0dc8.setContent(html_8071b3bfc80376c7dbac1807b2761959);
#
#
#
#         marker_084243cfd06f3e56feb21d551eefcd1d.bindPopup(popup_fb8c145c634f0ba241ed9c8067af0dc8)
#         ;
#
#
#
#
#             var marker_5b8a64a5ebf49d140fae4020867a6163 = L.marker(
#                 [46.029708862

# %% [markdown]
# ### Save data to file

# %%
df.to_csv('bmw_data_geocoded.csv', 
           sep=",", 
           encoding='utf-8',
           index=False)

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
